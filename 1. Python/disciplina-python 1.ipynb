# %% [markdown]
# # Exercício 1

# %% [markdown]
# a) Crie um ambiente chamado "disciplina-python".

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# b) Instale o pacote "numpy".

# %%
# !pip install numpy

# %% [markdown]
# c) Instale o Spyder.

# %%
# !pip install spyder

# %% [markdown]
# d) Tire printscreen das telas dos programas, mostrando que o anaconda, o
# ambiente com o pacote numpy, e o spyder foram instalado na sua
# máquina.

# %% [markdown]
# ![Captura de tela 2025-09-15 142210.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 2

# %% [markdown]
# Escreva um programa para solicitar ao usuário a quantidade de horas
# trabalhadas e o valor da hora de trabalho para calcular o total a ser recebido por esse funcionário.

# %% [markdown]
# Exemplo:
#
# 1.   Informe a quantidade de horas trabalhadas: 35
# 2.   Informe o valor da hora: 2.75
# 3.   Total a receber: 96.25

# %%
x = int(input("Informe a quantidade de horas trabalhadas:"))
y = float(input("Informe o valor da hora: "))
print("Total a receber: ", x*y)
# Out:
# Informe a quantidade de horas trabalhadas:35
# Informe o valor da hora: 2.75
# Total a receber:  96.25
